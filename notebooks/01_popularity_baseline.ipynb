# %% [markdown]
# # Popularity baseline
#
# Начинаю с тривиального ранжирования по частоте статьи в calibration.

# %%
from baseline import (
    build_popularity_ranking,
    evaluate_popularity,
    read_data,
)

# %%
articles, calibration, test = read_data()
ranking = build_popularity_ranking(calibration, articles["article_id"])
ranking
# Out:
# [4219, 1951, 4234, 2646, 4328, 4400, 4214, 4384, 4440, 4387]

# %%
evaluate_popularity(calibration, articles["article_id"])
# Out:
# 0.3158437830687831

# %% [markdown]
# Использую baseline как нижнюю границу. Он не учитывает текст запроса и возвращает один список всем пользователям.

# %% [markdown]
# > Для сохранения submission раскомментирую и выполняю следующую клетку.

# %%
# from baseline import OUTPUT_PATH, make_answer, validate_answer

# answer = make_answer(test, ranking)
# validate_answer(answer, test, articles["article_id"])
# OUTPUT_PATH.parent.mkdir(parents=True, exist_ok=True)
# answer.to_csv(OUTPUT_PATH, index=False)
# OUTPUT_PATH
