# %% [markdown]
# # XGBoost pairwise
#
# Я обучаю второй ranker с pairwise objective на том же наборе кандидатов.

# %%
import sys
from pathlib import Path

import pandas as pd

ROOT = Path(".")
DATA_DIR = ROOT / "statement" / "candidate_public" / "candidate_data"
sys.path.insert(0, str(ROOT / "src"))
results = pd.read_csv(ROOT / "outputs" / "experiment_results.csv")

# %%
results[results["approach"] == "XGBoost pairwise"]
# Out:
#     stage          approach    MAP@10         validation
# 6  Ranker  XGBoost pairwise  0.694662  nested 5-fold OOF

# %%
config = {"objective": "rank:pairwise", "max_depth": 4, "n_estimators": 350}
config
# Out:
# {'objective': 'rank:pairwise', 'max_depth': 4, 'n_estimators': 350}

# %% [markdown]
# Я оставляю XGBoost в ансамбле: по MAP@10 он близок к LightGBM, но даёт другой порядок статей.

# %% [markdown]
# > Для сохранения submission я раскомментирую и выполняю следующую клетку.

# %%
# from pipeline import fit_predict

# answer = fit_predict(DATA_DIR)
# OUTPUT_PATH = ROOT / "outputs" / "answer.csv"
# answer.to_csv(OUTPUT_PATH, index=False)
# OUTPUT_PATH
