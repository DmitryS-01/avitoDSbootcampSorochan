# %% [markdown]
# # Финальный pipeline
#
# Проверяю submission и воспроизводимость финального power blend.

# %%
import sys
from pathlib import Path

import pandas as pd

ROOT = Path(".")
DATA_DIR = ROOT / "statement" / "candidate_public" / "candidate_data"
sys.path.insert(0, str(ROOT / "src"))
results = pd.read_csv(ROOT / "outputs" / "experiment_results.csv")

# %%
from data import read_feather
from metrics import validate_answer

answer = pd.read_csv(ROOT / "outputs/answer.csv")
test = read_feather(DATA_DIR / "test.f")
articles = read_feather(DATA_DIR / "articles.f")
validate_answer(answer, test, articles["article_id"].astype(int).to_numpy())
answer.head()
# Out:
#    query_id                                             answer
# 0         1  4234 4308 4396 1951 1899 4219 4328 4361 1909 4384
# 1         2  2646 4234 4400 1966 4219 4384 4009 3843 4286 4328
# 2         3  4234 1909 4400 4328 4308 4219 1907 4396 4286 2646
# 3         4  4234 2646 1966 2865 4400 4219 4214 2698 3149 4384
# 4         5  4214 2698 1951 4308 4219 2646 4234 2665 4286 4328

# %%
results.tail(6)
# Out:
#              stage                                        approach    MAP@10  \
# 6           Ranker                             LightGBM LambdaMART  0.690997
# 7            Blend                             E5 + LightGBM blend  0.692786
# 8           Ranker                             Noise/spell XGBoost  0.685500
# 9   Previous blend                     E5 + LightGBM + noise/spell  0.696039
# 10          Ranker                         AutoML-selected XGBoost  0.682370
# 11           Final  E5 + LightGBM + AutoML XGBoost + cross-encoder  0.695062
#
#            validation
# 6   nested 5-fold OOF
# 7   nested 5-fold OOF
# 8   nested 5-fold OOF
# 9   nested 5-fold OOF
# 10  nested 5-fold OOF
# 11  nested 5-fold OOF

# %% [markdown]
# Финальный submission пересчитывается из корня командой `python run.py` или клеткой ниже.

# %% [markdown]
# > Этой клеткой пересчитываю и сохраняю текущий submission.

# %%
from pipeline import fit_predict

answer = fit_predict(DATA_DIR)
OUTPUT_PATH = ROOT / "outputs" / "answer.csv"
answer.to_csv(OUTPUT_PATH, index=False)
OUTPUT_PATH
# Out:
# PosixPath('outputs/answer.csv')
