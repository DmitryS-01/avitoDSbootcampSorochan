# %% [markdown]
# # Query kNN
#
# Ищу похожие размеченные запросы в char TF-IDF и переношу их article_id с весом по cosine similarity.

# %%
import sys
from pathlib import Path

import pandas as pd

ROOT = Path(".")
DATA_DIR = ROOT / "statement" / "candidate_public" / "candidate_data"
sys.path.insert(0, str(ROOT / "src"))
results = pd.read_csv(ROOT / "outputs" / "experiment_results.csv")

# %%
results[results["approach"] == "Query kNN"]
# Out:
#                   stage   approach    MAP@10  validation
# 3  Supervised retrieval  Query kNN  0.600823  5-fold OOF

# %%
config = {"space": "char_wb 3-5", "neighbors": 80, "weight": "similarity ** 3"}
config
# Out:
# {'space': 'char_wb 3-5', 'neighbors': 80, 'weight': 'similarity ** 3'}

# %% [markdown]
# Оставляю query kNN как самый сильный простой метод: похожие пользовательские сценарии часто описываются разными словами.

# %% [markdown]
# > Для сохранения submission раскомментирую и выполняю следующую клетку.

# %%
# from pipeline import fit_predict

# answer = fit_predict(DATA_DIR)
# OUTPUT_PATH = ROOT / "outputs" / "answer.csv"
# answer.to_csv(OUTPUT_PATH, index=False)
# OUTPUT_PATH
