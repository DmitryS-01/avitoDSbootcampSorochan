# %% [markdown]
# # BM25 и stemming
#
# Я сравниваю BM25 по видимому тексту и по stemmed-представлению.

# %%
import sys
from pathlib import Path

import pandas as pd

ROOT = Path(".")
DATA_DIR = ROOT / "statement" / "candidate_public" / "candidate_data"
sys.path.insert(0, str(ROOT / "src"))
results = pd.read_csv(ROOT / "outputs" / "experiment_results.csv")

# %%
results[results["approach"].isin(["BM25", "Stemmed BM25"])]
# Out:
#      stage      approach    MAP@10  validation
# 1  Lexical          BM25  0.269437  5-fold OOF
# 2  Lexical  Stemmed BM25  0.318739  5-fold OOF

# %%
from features import SparseBM25

bm25 = SparseBM25(ngram_range=(1, 2), max_features=150_000)
type(bm25).__name__
# Out:
# 'SparseBM25'

# %% [markdown]
# Я использую stemming как дополнительный сигнал для русской морфологии, но не полагаюсь только на лексическое совпадение.

# %% [markdown]
# > Для сохранения submission я раскомментирую и выполняю следующую клетку.

# %%
# from pipeline import fit_predict

# answer = fit_predict(DATA_DIR)
# OUTPUT_PATH = ROOT / "outputs" / "answer.csv"
# answer.to_csv(OUTPUT_PATH, index=False)
# OUTPUT_PATH
